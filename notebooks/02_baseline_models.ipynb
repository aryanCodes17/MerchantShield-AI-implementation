# %% [markdown]
# # 02 — Baseline models
#
# Training lives in `scripts/train.py` so notebooks cannot accidentally touch the test set.
# This notebook reads the **validation** comparison table produced by that pipeline.
#
# Accuracy is not used as a selection metric.

# %%
from pathlib import Path
import pandas as pd
import json

root = Path('..')
print(pd.read_csv(root / 'reports' / 'model_comparison.csv'))
meta = json.loads((root / 'models' / 'model_metadata.json').read_text())
print('Selected:', meta['model_name'])
print(meta['selection_reason'])
